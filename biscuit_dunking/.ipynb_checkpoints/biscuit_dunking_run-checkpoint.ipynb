# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error
import AI_DL_project2 as pf2

# %% [markdown]
# # Reading in data

# %%
dunking_data = pd.read_csv('dunking-data.csv')
dunking_data.head()
# Out:
#       gamma       phi       eta         L          t    biscuit
# 0  0.073897  1.333006  0.000999  0.011196  19.362214  Digestive
# 1  0.080946  1.476758  0.001012  0.005894  11.852589  Digestive
# 2  0.087408  1.477141  0.000984  0.009249  24.793669  Digestive
# 3  0.070793  1.502001  0.001002  0.003774  16.292780     Hobnob
# 4  0.058917  1.548274  0.001004  0.002291  13.662271     Hobnob

# %%
micro_measure = pd.read_csv('microscopy-data.csv')
micro_measure.head()
# Out:
#       gamma       phi       eta         L          t             r
# 0  0.084596  1.557367  0.000981  0.003221  24.231107  7.453712e-07
# 1  0.064291  1.538842  0.000998  0.002395  22.169765  2.600680e-07
# 2  0.086224  1.546138  0.001008  0.003036  23.257709  3.734618e-07
# 3  0.082859  1.566878  0.000997  0.001261  12.717432  7.567173e-07
# 4  0.090832  1.570229  0.001002  0.000576  15.189146  8.239067e-07

# %%
time_resolve_1 = pd.read_csv('tr-1.csv')
time_resolve_1.head()
# Out:
#            t         L        dL
# 0  30.000000  0.008087  0.000392
# 1  32.727273  0.008253  0.000270
# 2  35.454545  0.008607  0.000501
# 3  38.181818  0.008920  0.000267
# 4  40.909091  0.009604  0.000274

# %%
time_resolve_2 = pd.read_csv('tr-2.csv')
time_resolve_2.head()
# Out:
#            t         L        dL
# 0  30.000000  0.005809  0.000228
# 1  32.727273  0.006243  0.000514
# 2  35.454545  0.006394  0.000393
# 3  38.181818  0.006601  0.000323
# 4  40.909091  0.006822  0.000566

# %%
time_resolve_3 = pd.read_csv('tr-3.csv')
time_resolve_3.head()
# Out:
#            t         L        dL
# 0  30.000000  0.011187  0.000371
# 1  32.727273  0.011566  0.000609
# 2  35.454545  0.011942  0.000809
# 3  38.181818  0.012502  0.000614
# 4  40.909091  0.013343  0.000480

# %% [markdown]
# # Estimating pore radius from capillary flow
#
# Using the Washburn equation and tr-1.csv, ts-2.csv, tr-3.csv files.

# %%
pf2.pore_rad_est(time_resolve_1)
# Out:
#            t         L        dL         r_est
# 0  30.000000  0.008087  0.000392  1.277229e-07
# 1  32.727273  0.008253  0.000270  1.219267e-07
# 2  35.454545  0.008607  0.000501  1.224093e-07
# 3  38.181818  0.008920  0.000267  1.220934e-07
# 4  40.909091  0.009604  0.000274  1.320901e-07

# %%
pf2.pore_rad_est(time_resolve_2)
# Out:
#            t         L        dL         r_est
# 0  30.000000  0.005809  0.000228  6.589752e-08
# 1  32.727273  0.006243  0.000514  6.976904e-08
# 2  35.454545  0.006394  0.000393  6.756403e-08
# 3  38.181818  0.006601  0.000323  6.686460e-08
# 4  40.909091  0.006822  0.000566  6.663931e-08

# %%
pf2.pore_rad_est(time_resolve_3)
# Out:
#            t         L        dL         r_est
# 0  30.000000  0.011187  0.000371  2.444047e-07
# 1  32.727273  0.011566  0.000609  2.394695e-07
# 2  35.454545  0.011942  0.000809  2.356314e-07
# 3  38.181818  0.012502  0.000614  2.398212e-07
# 4  40.909091  0.013343  0.000480  2.549409e-07

# %% [markdown]
# # Can a machine learning algorithm identify the different types of biscuits?
#
# Using a random forest classifier and dunking-data.csv, tr-1.csv, tr-2.csv, tr-3.csv files.

# %%
X = dunking_data[['L', 't']]
y = dunking_data['biscuit']

# %%
pf2.classifier(X, y, time_resolve_1)
# Out:
# Accuracy: 0.40166666666666667
#               precision    recall  f1-score   support
#
#    Digestive       0.46      0.46      0.46       204
#       Hobnob       0.35      0.31      0.33       203
#     Rich Tea       0.39      0.45      0.42       193
#
#     accuracy                           0.40       600
#    macro avg       0.40      0.40      0.40       600
# weighted avg       0.40      0.40      0.40       600
#            t         L        dL         r_est biscuit_pred
# 0  30.000000  0.008087  0.000392  1.277229e-07       Hobnob
# 1  32.727273  0.008253  0.000270  1.219267e-07       Hobnob
# 2  35.454545  0.008607  0.000501  1.224093e-07       Hobnob
# 3  38.181818  0.008920  0.000267  1.220934e-07     Rich Tea
# 4  40.909091  0.009604  0.000274  1.320901e-07     Rich Tea

# %%
pf2.classifier(X, y, time_resolve_2)
# Out:
# Accuracy: 0.40166666666666667
#               precision    recall  f1-score   support
#
#    Digestive       0.46      0.46      0.46       204
#       Hobnob       0.35      0.31      0.33       203
#     Rich Tea       0.39      0.45      0.42       193
#
#     accuracy                           0.40       600
#    macro avg       0.40      0.40      0.40       600
# weighted avg       0.40      0.40      0.40       600
#            t         L        dL         r_est biscuit_pred
# 0  30.000000  0.005809  0.000228  6.589752e-08     Rich Tea
# 1  32.727273  0.006243  0.000514  6.976904e-08     Rich Tea
# 2  35.454545  0.006394  0.000393  6.756403e-08     Rich Tea
# 3  38.181818  0.006601  0.000323  6.686460e-08     Rich Tea
# 4  40.909091  0.006822  0.000566  6.663931e-08     Rich Tea

# %%
pf2.classifier(X, y, time_resolve_3)
# Out:
# Accuracy: 0.40166666666666667
#               precision    recall  f1-score   support
#
#    Digestive       0.46      0.46      0.46       204
#       Hobnob       0.35      0.31      0.33       203
#     Rich Tea       0.39      0.45      0.42       193
#
#     accuracy                           0.40       600
#    macro avg       0.40      0.40      0.40       600
# weighted avg       0.40      0.40      0.40       600
#            t         L        dL         r_est biscuit_pred
# 0  30.000000  0.011187  0.000371  2.444047e-07    Digestive
# 1  32.727273  0.011566  0.000609  2.394695e-07    Digestive
# 2  35.454545  0.011942  0.000809  2.356314e-07    Digestive
# 3  38.181818  0.012502  0.000614  2.398212e-07    Digestive
# 4  40.909091  0.013343  0.000480  2.549409e-07    Digestive

# %% [markdown]
# # How is the pore radius different between the three types of biscuits?
#
# First test done by merging microscopy-data.csv and dunking-data.csv files and plotting the data.

# %%
micro_dunking = pd.merge(micro_measure, dunking_data, on=['gamma', 'phi', 'eta', 'L', 't'])
micro_dunking.head()
# Out:
#       gamma       phi       eta         L          t             r    biscuit
# 0  0.084596  1.557367  0.000981  0.003221  24.231107  7.453712e-07  Digestive
# 1  0.064291  1.538842  0.000998  0.002395  22.169765  2.600680e-07   Rich Tea
# 2  0.086224  1.546138  0.001008  0.003036  23.257709  3.734618e-07     Hobnob
# 3  0.082859  1.566878  0.000997  0.001261  12.717432  7.567173e-07  Digestive
# 4  0.090832  1.570229  0.001002  0.000576  15.189146  8.239067e-07  Digestive

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(x=micro_dunking['biscuit'], y=micro_dunking['r'])
ax.set(xlabel="Biscuit Type", ylabel="Pore Radius (m)", title="Comparison of Pore Radius Across Biscuit Types")
plt.show()

# %% [markdown]
# # Time-series analysis of liquid absoroption
#
# Using derivative analysis and the tr-1.csv, tr-2.csv, tr-3.csv files.

# %%
pf2.absorb_time(time_resolve_1)
# Out:
#            t         L        dL         r_est biscuit_pred     dL_dt
# 0  30.000000  0.008087  0.000392  1.277229e-07       Hobnob  0.000061
# 1  32.727273  0.008253  0.000270  1.219267e-07       Hobnob  0.000095
# 2  35.454545  0.008607  0.000501  1.224093e-07       Hobnob  0.000122
# 3  38.181818  0.008920  0.000267  1.220934e-07     Rich Tea  0.000183
# 4  40.909091  0.009604  0.000274  1.320901e-07     Rich Tea  0.000142

# %%
pf2.absorb_time(time_resolve_2)
# Out:
#            t         L        dL         r_est biscuit_pred     dL_dt
# 0  30.000000  0.005809  0.000228  6.589752e-08     Rich Tea  0.000159
# 1  32.727273  0.006243  0.000514  6.976904e-08     Rich Tea  0.000107
# 2  35.454545  0.006394  0.000393  6.756403e-08     Rich Tea  0.000066
# 3  38.181818  0.006601  0.000323  6.686460e-08     Rich Tea  0.000078
# 4  40.909091  0.006822  0.000566  6.663931e-08     Rich Tea  0.000087

# %%
pf2.absorb_time(time_resolve_3)
# Out:
#            t         L        dL         r_est biscuit_pred     dL_dt
# 0  30.000000  0.011187  0.000371  2.444047e-07    Digestive  0.000139
# 1  32.727273  0.011566  0.000609  2.394695e-07    Digestive  0.000138
# 2  35.454545  0.011942  0.000809  2.356314e-07    Digestive  0.000172
# 3  38.181818  0.012502  0.000614  2.398212e-07    Digestive  0.000257
# 4  40.909091  0.013343  0.000480  2.549409e-07    Digestive  0.000158

# %% [markdown]
# # How accurate is the Washburn equation for biscuits, and can a machine learning regressor perform better?
#
# Comparing washburn equation to random forest regressor using the merged microscopy-data.csv and dunking-data.csv files.

# %%
micro_dunking['washburn_eq'] = pf2.washburn_eq(micro_dunking['gamma'], micro_dunking['r'], micro_dunking['t'], micro_dunking['phi'], micro_dunking['eta'])
micro_dunking.head()
# Out:
#       gamma       phi       eta         L          t             r    biscuit  \
# 0  0.084596  1.557367  0.000981  0.003221  24.231107  7.453712e-07  Digestive
# 1  0.064291  1.538842  0.000998  0.002395  22.169765  2.600680e-07   Rich Tea
# 2  0.086224  1.546138  0.001008  0.003036  23.257709  3.734618e-07     Hobnob
# 3  0.082859  1.566878  0.000997  0.001261  12.717432  7.567173e-07  Digestive
# 4  0.090832  1.570229  0.001002  0.000576  15.189146  8.239067e-07  Digestive
#
#    washburn_eq
# 0     0.003233
# 1     0.002436
# 2     0.003027
# 3     0.001251
# 4     0.000567

# %%
X = micro_dunking[['gamma', 'phi', 'eta', 't', 'r']]
y = micro_dunking['L']

# %%
pf2.regressor_washburn(X, y, micro_dunking)
# Out:
# Washburn Equation MSE: 0.000000
# Regressor Model MSE: 0.000001
